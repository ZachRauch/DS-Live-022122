# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## Objectives
#
# - Send requests and receive responses over the web
# - Retrieve data from APIs using the `requests` library
# - Parse API responses

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"20717383120","type":"PushEvent","actor":{"id":79544226,"login":"shopify[bot]","display_login":"shopify","gravatar_id":"","url":"https://api.github.com/users/shopify[bot]","avatar_url":"https://avatars.githubusercontent.com/u/79544226?"},"repo":{"id":449470164,"name":"elemental-digital/dawn","url":"https://api.github.com/repos/elemental-digital/dawn"},"payload":{"push_id":9335698260,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"4e60556853318f2dcab5099f5f41268b32ee962e","before":"d033e34335440816d567ce50c3cf61a21c0c5bca","commits":[{"sha":"4e60556853318f2dcab5099f5f41268b32ee962e","author":{"email":"79544226+shopify[bot]@users.noreply.github.com","name":"shopify[bot]"},"message":"Update from Shopify for theme dawn/main\\n\\nCommitted from shop: clinicians development","distinct":true,"url":"https://api.github.com/repos/elemental-digital/dawn/commits/4e60556853318f2dcab5099f5f41268b32ee962e"}]},"public":true,"created_at":"2022-03-12T21:27:09Z","org":{"id":97779350,"login":"elemental-digital","gravatar_id":"","url":"https://api.github.com/orgs/elemental-digital","avatar_url":"https://avatars.githubusercontent.com/u/97779350?"}},{"id":"20717383117","type":"PushEvent","actor":{"id":94253815,"login":"RHilburn75","display_login":"RHilburn75","gravatar_id":"","url":"https://api.github.com/users/RHilburn75","avatar_url":"https://avatars.githubusercontent.com/u/94253815?"},"repo":{"id":467712717,"name":"RHilburn75/MechaCar_Statistical_Analysis","url":"https://api.github.com/repos/RHilburn75/MechaCar_Statistical_Analysis"},"payload":{"push_id":9335698266,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"3c7349173f1f29378ebadf495eae63c3dc1053a6","before":"44bffd1052339b1a7b46f26aef1e9c126dee662a","commits":[{"sha":"3c7349173f1f29378ebadf495eae63c3dc1053a6","author":{"email":"94253815+RHilburn75@users.noreply.github.com","name":"RHilburn75"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/RHilburn75/MechaCar_Statistical_Analysis/commits/3c7349173f1f29378ebadf495eae63c3dc1053a6"}]},"public":true,"created_at":"2022-03-12T21:27:09Z"},{"id":"20717383119","type":"PushEvent","actor":{"id":97787208,"login":"alaawatch13","display_login":"alaawatch13","gravatar_id":"","url":"https://api.github.com/users/alaawatch13","avatar_url":"https://avatars.githubusercontent.com/u/97787208?"},"repo":{"id":448253801,"name":"alaawatch13/st2","url":"https://api.github.com/repos/alaawatch13/st2"},"payload":{"push_id":9335698263,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"1f685dbdaa16b05f026f9c544432318244147d1d","before":"7c64217fc85cfbe4fc9b808f0a2ed93b4fee6650","commits":[{"sha":"1f685dbdaa16b05f026f9c544432318244147d1d","author":{"email":"97787208+alaawatch13@users.noreply.github.com","name":"alaawatch13"},"message":"m3u8 file","distinct":true,"url":"https://api.github.com/repos/alaawatch13/st2/commits/1f685dbdaa16b05f026f9c544432318244147d1d"}]},"public":true,"created_at":"2022-03-12T21:27:09Z"},{"id":"20717383099","type":"PushEvent","actor":{"id":25119437,"login":"ignissak","display_login":"ignissak","gravatar_id":"","url":"https://api.github.com/users/ignissak","avatar_url":"https://avatars.githubusercontent.com/u/25119437?"},"repo":{"id":295162994,"name":"ignissak/ignissak","url":"https://api.github.com/repos/ignissak/ignissak"},"payload":{"push_id":9335698257,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"ac94038e85621ef3cf51944d75875b53d9cf59e1","before":"a0bf63306f097f8f4e685233ac1de3a2e3082861","commits":[{"sha":"ac94038e85621ef3cf51944d75875b53d9cf59e1","author":{"email":"41898282+github-actions[bot]@users.noreply.github.com","name":"readme-bot"},"message":"Updated with Dev Metrics","distinct":true,"url":"https://api.github.com/repos/ignissak/ignissak/commits/ac94038e85621ef3cf51944d75875b53d9cf59e1"}]},"public":true,"created_at":"2022-03-12T21:27:09Z"},{"id":"20717383111","type":"PushEvent","actor":{"id":91560218,"login":"soberhippie3","display_login":"soberhip ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Sat, 12 Mar 2022 21:32:09 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"70a95a20d9cebf428e8abe33dfed7b26c4f7733c1098b72940abc05142b231b0"', 'Last-Modified': 'Sat, 12 Mar 2022 21:27:09 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1647124329', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'F3B8:0335:26BE93B:58E9A7A:622D1159'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '20717383120',
#   'type': 'PushEvent',
#   'actor': {'id': 79544226,
#    'login': 'shopify[bot]',
#    'display_login': 'shopify',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shopify[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79544226?'},
#   'repo': {'id': 449470164,
#    'name': 'elemental-digital/dawn',
#    'url': 'https://api.github.com/repos/elemental-digital/dawn'},
#   'payload': {'push_id': 9335698260,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4e60556853318f2dcab5099f5f41268b32ee962e',
#    'before': 'd033e34335440816d567ce50c3cf61a21c0c5bca',
#    'commits': [{'sha': '4e60556853318f2dcab5099f5f41268b32ee962e',
#      'author': {'email': '79544226+shopify[bot]@users.noreply.github.com',
#       'name': 'shopify[bot]'},
#      'message': 'Update from Shopify for theme dawn/main\n\nCommitted from shop: clinicians development',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/elemental-digital/dawn/commits/4e60556853318f2dcab5099f5f41268b32ee962e'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z',
#   'org': {'id': 97779350,
#    'login': 'elemental-digital',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/elemental-digital',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97779350?'}},
#  {'id': '20717383117',
#   'type': 'PushEvent',
#   'actor': {'id': 94253815,
#    'login': 'RHilburn75',
#    'display_login': 'RHilburn75',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RHilburn75',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94253815?'},
#   'repo': {'id': 467712717,
#    'name': 'RHilburn75/MechaCar_Statistical_Analysis',
#    'url': 'https://api.github.com/repos/RHilburn75/MechaCar_Statistical_Analysis'},
#   'payload': {'push_id': 9335698266,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3c7349173f1f29378ebadf495eae63c3dc1053a6',
#    'before': '44bffd1052339b1a7b46f26aef1e9c126dee662a',
#    'commits': [{'sha': '3c7349173f1f29378ebadf495eae63c3dc1053a6',
#      'author': {'email': '94253815+RHilburn75@users.noreply.github.com',
#       'name': 'RHilburn75'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RHilburn75/MechaCar_Statistical_Analysis/commits/3c7349173f1f29378ebadf495eae63c3dc1053a6'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z'},
#  {'id': '20717383119',
#   'type': 'PushEvent',
#   'actor': {'id': 97787208,
#    'login': 'alaawatch13',
#    'display_login': 'alaawatch13',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alaawatch13',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97787208?'},
#   'repo': {'id': 448253801,
#    'name': 'alaawatch13/st2',
#    'url': 'https://api.github.com/repos/alaawatch13/st2'},
#   'payload': {'push_id': 9335698263,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1f685dbdaa16b05f026f9c544432318244147d1d',
#    'before': '7c64217fc85cfbe4fc9b808f0a2ed93b4fee6650',
#    'commits': [{'sha': '1f685dbdaa16b05f026f9c544432318244147d1d',
#      'author': {'email': '97787208+alaawatch13@users.noreply.github.com',
#       'name': 'alaawatch13'},
#      'message': 'm3u8 file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alaawatch13/st2/commits/1f685dbdaa16b05f026f9c544432318244147d1d'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z'},
#  {'id': '20717383099',
#   'type': 'PushEvent',
#   'actor': {'id': 25119437,
#    'login': 'ignissak',
#    'display_login': 'ignissak',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ignissak',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25119437?'},
#   'repo': {'id': 295162994,
#    'name': 'ignissak/ignissak',
#    'url': 'https://api.github.com/repos/ignissak/ignissak'},
#   'payload': {'push_id': 9335698257,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ac94038e85621ef3cf51944d75875b53d9cf59e1',
#    'before': 'a0bf63306f097f8f4e685233ac1de3a2e3082861',
#    'commits': [{'sha': 'ac94038e85621ef3cf51944d75875b53d9cf59e1',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'readme-bot'},
#      'message': 'Updated with Dev Metrics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ignissak/ignissak/commits/ac94038e85621ef3cf51944d75875b53d9cf59e1'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z'},
#  {'id': '20717383111',
#   'type': 'PushEvent',
#   'actor': {'id': 91560218,
#    'login': 'soberhippie3',
#    'display_login': 'soberhippie3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/soberhippie3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91560218?'},
#   'repo': {'id': 450635025,
#    'name': 'soberhippie3/archinstall',
#    'url': 'https://api.github.com/repos/soberhippie3/archinstall'},
#   'payload': {'push_id': 9335698261,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2fb87b0d75213a6fbefc88737757a4c17d246f15',
#    'before': '25fddd02d2a470f88f48c0f6a336c25188aa7624',
#    'commits': [{'sha': '2fb87b0d75213a6fbefc88737757a4c17d246f15',
#      'author': {'email': '91560218+soberhippie3@users.noreply.github.com',
#       'name': 'soberhippie3'},
#      'message': 'Update packages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/soberhippie3/archinstall/commits/2fb87b0d75213a6fbefc88737757a4c17d246f15'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z'},
#  {'id': '20717383107',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 1177433,
#    'login': 'ikashyntseva',
#    'display_login': 'ikashyntseva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ikashyntseva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1177433?'},
#   'repo': {'id': 456697914,
#    'name': 'htmlacademy-react/169447-six-cities-9',
#    'url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9'},
#   'payload': {'action': 'opened',
#    'number': 13,
#    'pull_request': {'url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/13',
#     'id': 878257606,
#     'node_id': 'PR_kwDOGzioOs40WSXG',
#     'html_url': 'https://github.com/htmlacademy-react/169447-six-cities-9/pull/13',
#     'diff_url': 'https://github.com/htmlacademy-react/169447-six-cities-9/pull/13.diff',
#     'patch_url': 'https://github.com/htmlacademy-react/169447-six-cities-9/pull/13.patch',
#     'issue_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/issues/13',
#     'number': 13,
#     'state': 'open',
#     'locked': False,
#     'title': '8.10. Оптимизируй это (Часть 1)',
#     'user': {'login': 'ikashyntseva',
#      'id': 1177433,
#      'node_id': 'MDQ6VXNlcjExNzc0MzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1177433?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ikashyntseva',
#      'html_url': 'https://github.com/ikashyntseva',
#      'followers_url': 'https://api.github.com/users/ikashyntseva/followers',
#      'following_url': 'https://api.github.com/users/ikashyntseva/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ikashyntseva/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ikashyntseva/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ikashyntseva/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ikashyntseva/orgs',
#      'repos_url': 'https://api.github.com/users/ikashyntseva/repos',
#      'events_url': 'https://api.github.com/users/ikashyntseva/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ikashyntseva/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-03-12T21:27:09Z',
#     'updated_at': '2022-03-12T21:27:09Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/13/commits',
#     'review_comments_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/13/comments',
#     'review_comment_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/issues/13/comments',
#     'statuses_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/statuses/4ee4ff5b6823a647b9a392613abaa000b9c4b941',
#     'head': {'label': 'ikashyntseva:module8-task1',
#      'ref': 'module8-task1',
#      'sha': '4ee4ff5b6823a647b9a392613abaa000b9c4b941',
#      'user': {'login': 'ikashyntseva',
#       'id': 1177433,
#       'node_id': 'MDQ6VXNlcjExNzc0MzM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1177433?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ikashyntseva',
#       'html_url': 'https://github.com/ikashyntseva',
#       'followers_url': 'https://api.github.com/users/ikashyntseva/followers',
#       'following_url': 'https://api.github.com/users/ikashyntseva/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ikashyntseva/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ikashyntseva/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ikashyntseva/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ikashyntseva/orgs',
#       'repos_url': 'https://api.github.com/users/ikashyntseva/repos',
#       'events_url': 'https://api.github.com/users/ikashyntseva/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ikashyntseva/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 456698245,
#       'node_id': 'R_kgDOGziphQ',
#       'name': '169447-six-cities-9',
#       'full_name': 'ikashyntseva/169447-six-cities-9',
#       'private': False,
#       'owner': {'login': 'ikashyntseva',
#        'id': 1177433,
#        'node_id': 'MDQ6VXNlcjExNzc0MzM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1177433?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ikashyntseva',
#        'html_url': 'https://github.com/ikashyntseva',
#        'followers_url': 'https://api.github.com/users/ikashyntseva/followers',
#        'following_url': 'https://api.github.com/users/ikashyntseva/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ikashyntseva/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ikashyntseva/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ikashyntseva/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ikashyntseva/orgs',
#        'repos_url': 'https://api.github.com/users/ikashyntseva/repos',
#        'events_url': 'https://api.github.com/users/ikashyntseva/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ikashyntseva/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ikashyntseva/169447-six-cities-9',
#       'description': 'Irina Kashyntseva',
#       'fork': True,
#       'url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9',
#       'forks_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/forks',
#       'keys_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/teams',
#       'hooks_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/events',
#       'assignees_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/tags',
#       'blobs_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/languages',
#       'stargazers_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/subscription',
#       'commits_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/merges',
#       'archive_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/downloads',
#       'issues_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ikashyntseva/169447-six-cities-9/deployments',
#       'created_at': '2022-02-07T22:24:31Z',
#       'updated_at': '2022-02-08T09:04:04Z',
#       'pushed_at': '2022-03-12T21:26:30Z',
#       'git_url': 'git://github.com/ikashyntseva/169447-six-cities-9.git',
#       'ssh_url': 'git@github.com:ikashyntseva/169447-six-cities-9.git',
#       'clone_url': 'https://github.com/ikashyntseva/169447-six-cities-9.git',
#       'svn_url': 'https://github.com/ikashyntseva/169447-six-cities-9',
#       'homepage': None,
#       'size': 3172,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'htmlacademy-react:master',
#      'ref': 'master',
#      'sha': '9dc9718ccbec75c9be93e711188a6c8988893e33',
#      'user': {'login': 'htmlacademy-react',
#       'id': 46160408,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2MTYwNDA4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/46160408?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/htmlacademy-react',
#       'html_url': 'https://github.com/htmlacademy-react',
#       'followers_url': 'https://api.github.com/users/htmlacademy-react/followers',
#       'following_url': 'https://api.github.com/users/htmlacademy-react/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/htmlacademy-react/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/htmlacademy-react/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/htmlacademy-react/subscriptions',
#       'organizations_url': 'https://api.github.com/users/htmlacademy-react/orgs',
#       'repos_url': 'https://api.github.com/users/htmlacademy-react/repos',
#       'events_url': 'https://api.github.com/users/htmlacademy-react/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/htmlacademy-react/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 456697914,
#       'node_id': 'R_kgDOGzioOg',
#       'name': '169447-six-cities-9',
#       'full_name': 'htmlacademy-react/169447-six-cities-9',
#       'private': False,
#       'owner': {'login': 'htmlacademy-react',
#        'id': 46160408,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2MTYwNDA4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/46160408?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/htmlacademy-react',
#        'html_url': 'https://github.com/htmlacademy-react',
#        'followers_url': 'https://api.github.com/users/htmlacademy-react/followers',
#        'following_url': 'https://api.github.com/users/htmlacademy-react/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/htmlacademy-react/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/htmlacademy-react/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/htmlacademy-react/subscriptions',
#        'organizations_url': 'https://api.github.com/users/htmlacademy-react/orgs',
#        'repos_url': 'https://api.github.com/users/htmlacademy-react/repos',
#        'events_url': 'https://api.github.com/users/htmlacademy-react/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/htmlacademy-react/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/htmlacademy-react/169447-six-cities-9',
#       'description': 'Irina Kashyntseva',
#       'fork': False,
#       'url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9',
#       'forks_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/forks',
#       'keys_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/teams',
#       'hooks_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/hooks',
#       'issue_events_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/events',
#       'assignees_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/tags',
#       'blobs_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/languages',
#       'stargazers_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/stargazers',
#       'contributors_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/contributors',
#       'subscribers_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/subscribers',
#       'subscription_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/subscription',
#       'commits_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/merges',
#       'archive_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/downloads',
#       'issues_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/deployments',
#       'created_at': '2022-02-07T22:23:14Z',
#       'updated_at': '2022-02-07T22:30:33Z',
#       'pushed_at': '2022-03-12T07:43:20Z',
#       'git_url': 'git://github.com/htmlacademy-react/169447-six-cities-9.git',
#       'ssh_url': 'git@github.com:htmlacademy-react/169447-six-cities-9.git',
#       'clone_url': 'https://github.com/htmlacademy-react/169447-six-cities-9.git',
#       'svn_url': 'https://github.com/htmlacademy-react/169447-six-cities-9',
#       'homepage': 'https://github.com/ikashyntseva/169447-six-cities-9',
#       'size': 3172,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/13'},
#      'html': {'href': 'https://github.com/htmlacademy-react/169447-six-cities-9/pull/13'},
#      'issue': {'href': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/issues/13'},
#      'comments': {'href': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/issues/13/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/13/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/pulls/13/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/htmlacademy-react/169447-six-cities-9/statuses/4ee4ff5b6823a647b9a392613abaa000b9c4b941'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 531,
#     'deletions': 336,
#     'changed_files': 34}},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z',
#   'org': {'id': 46160408,
#    'login': 'htmlacademy-react',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/htmlacademy-react',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46160408?'}},
#  {'id': '20717383096',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 347912975,
#    'name': 'AppiumTestDistribution/appium-device-farm',
#    'url': 'https://api.github.com/repos/AppiumTestDistribution/appium-device-farm'},
#   'payload': {'ref': 'renovate/typescript-4.x',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z',
#   'org': {'id': 44707594,
#    'login': 'AppiumTestDistribution',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/AppiumTestDistribution',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44707594?'}},
#  {'id': '20717383093',
#   'type': 'PushEvent',
#   'actor': {'id': 62388527,
#    'login': 'Ruddy9501',
#    'display_login': 'Ruddy9501',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ruddy9501',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62388527?'},
#   'repo': {'id': 464537183,
#    'name': 'Ruddy9501/Kaggle-competitions',
#    'url': 'https://api.github.com/repos/Ruddy9501/Kaggle-competitions'},
#   'payload': {'push_id': 9335698238,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0741c4651c46204c2b394ede4a3cfa41628d3a1a',
#    'before': 'adc741f750461f1d330d87c644f43db5c4cb9c32',
#    'commits': [{'sha': '0741c4651c46204c2b394ede4a3cfa41628d3a1a',
#      'author': {'email': 'rguerrero9501@gmail.com',
#       'name': 'Ruddy Guerrero Alvarez'},
#      'message': 'Changes in digit_recognizer.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ruddy9501/Kaggle-competitions/commits/0741c4651c46204c2b394ede4a3cfa41628d3a1a'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z'},
#  {'id': '20717383103',
#   'type': 'PushEvent',
#   'actor': {'id': 79913779,
#    'login': 'conda-forge-curator[bot]',
#    'display_login': 'conda-forge-curator',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/conda-forge-curator[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79913779?'},
#   'repo': {'id': 425269044,
#    'name': 'conda-forge/r-adabag-feedstock',
#    'url': 'https://api.github.com/repos/conda-forge/r-adabag-feedstock'},
#   'payload': {'push_id': 9335698245,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9a9924927922ab362e59eda4ca1b8b671f2bb7aa',
#    'before': 'e26e4e78c734128eb7d25b8ffbed0415b648d060',
#    'commits': [{'sha': '9a9924927922ab362e59eda4ca1b8b671f2bb7aa',
#      'author': {'email': 'pelson.pub+conda-forge@gmail.com',
#       'name': 'conda-forge-admin'},
#      'message': '[ci skip] [skip ci] [cf admin skip] ***NO_CI*** turning on CI for master to main migration',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/conda-forge/r-adabag-feedstock/commits/9a9924927922ab362e59eda4ca1b8b671f2bb7aa'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:09Z',
#   'org': {'id': 11897326,
#    'login': 'conda-forge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/conda-forge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11897326?'}},
#  {'id': '20717383097',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 93738479,
#    'login': 'armcuellar',
#    'display_login': 'armcuellar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/armcuellar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93738479?'},
#   'repo': {'id': 465940976,
#    'name': '8bitgaming/OgreQuest',
#    'url': 'https://api.github.com/repos/8bitgaming/OgreQuest'},
#   'payload': {'action': 'created',
#    'review': {'id': 908056339,
#     'node_id': 'PRR_kwDOG8Wx8M42H9cT',
#     'user': {'login': 'armcuellar',
#      'id': 93738479,
#      'node_id': 'U_kgDOBZZV7w',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/93738479?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/armcuellar',
#      'html_url': 'https://github.com/armcuellar',
#      'followers_url': 'https://api.github.com/users/armcuellar/followers',
#      'following_url': 'https://api.github.com/users/armcuellar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/armcuellar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/armcuellar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/armcuellar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/armcuellar/orgs',
#      'repos_url': 'https://api.github.com/users/armcuellar/repos',
#      'events_url': 'https://api.github.com/users/armcuellar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/armcuellar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': '8dcd7fa5bd0f348feb5fa3f85e894a461847ea83',
#     'submitted_at': '2022-03-12T21:27:09Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/8bitgaming/OgreQuest/pull/67#pullrequestreview-908056339',
#     'pull_request_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/pulls/67',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/8bitgaming/OgreQuest/pull/67#pullrequestreview-908056339'},
#      'pull_request': {'href': 'https://api.github.com/repos/8bitgaming/OgreQuest/pulls/67'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/8bitgaming/OgreQuest/pulls/67',
#     'id': 878199389,
#     'node_id': 'PR_kwDOG8Wx8M40WEJd',
#     'html_url': 'https://github.com/8bitgaming/OgreQuest/pull/67',
#     'diff_url': 'https://github.com/8bitgaming/OgreQuest/pull/67.diff',
#     'patch_url': 'https://github.com/8bitgaming/OgreQuest/pull/67.patch',
#     'issue_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/issues/67',
#     'number': 67,
#     'state': 'open',
#     'locked': False,
#     'title': 'fixes the console erorr for when all characters are deleted',
#     'user': {'login': 'gieskj01',
#      'id': 27291438,
#      'node_id': 'MDQ6VXNlcjI3MjkxNDM4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/27291438?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gieskj01',
#      'html_url': 'https://github.com/gieskj01',
#      'followers_url': 'https://api.github.com/users/gieskj01/followers',
#      'following_url': 'https://api.github.com/users/gieskj01/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gieskj01/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gieskj01/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gieskj01/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gieskj01/orgs',
#      'repos_url': 'https://api.github.com/users/gieskj01/repos',
#      'events_url': 'https://api.github.com/users/gieskj01/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gieskj01/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'To test - create a couple characters then delete them all with the inspect window open. No error messages should happen.',
#     'created_at': '2022-03-12T16:05:37Z',
#     'updated_at': '2022-03-12T21:27:09Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '57f4bbea85d1e4a8b1d8c6f72a222e1336ea3617',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'mmcelwee8002',
#       'id': 47764600,
#       'node_id': 'MDQ6VXNlcjQ3NzY0NjAw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/47764600?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mmcelwee8002',
#       'html_url': 'https://github.com/mmcelwee8002',
#       'followers_url': 'https://api.github.com/users/mmcelwee8002/followers',
#       'following_url': 'https://api.github.com/users/mmcelwee8002/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mmcelwee8002/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mmcelwee8002/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mmcelwee8002/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mmcelwee8002/orgs',
#       'repos_url': 'https://api.github.com/users/mmcelwee8002/repos',
#       'events_url': 'https://api.github.com/users/mmcelwee8002/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mmcelwee8002/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'dwetoskey',
#       'id': 93551304,
#       'node_id': 'U_kgDOBZN6yA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/93551304?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dwetoskey',
#       'html_url': 'https://github.com/dwetoskey',
#       'followers_url': 'https://api.github.com/users/dwetoskey/followers',
#       'following_url': 'https://api.github.com/users/dwetoskey/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dwetoskey/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dwetoskey/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dwetoskey/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dwetoskey/orgs',
#       'repos_url': 'https://api.github.com/users/dwetoskey/repos',
#       'events_url': 'https://api.github.com/users/dwetoskey/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dwetoskey/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/pulls/67/commits',
#     'review_comments_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/pulls/67/comments',
#     'review_comment_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/issues/67/comments',
#     'statuses_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/statuses/8dcd7fa5bd0f348feb5fa3f85e894a461847ea83',
#     'head': {'label': '8bitgaming:fixDeleteCharacter',
#      'ref': 'fixDeleteCharacter',
#      'sha': '8dcd7fa5bd0f348feb5fa3f85e894a461847ea83',
#      'user': {'login': '8bitgaming',
#       'id': 79021467,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5MDIxNDY3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/79021467?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/8bitgaming',
#       'html_url': 'https://github.com/8bitgaming',
#       'followers_url': 'https://api.github.com/users/8bitgaming/followers',
#       'following_url': 'https://api.github.com/users/8bitgaming/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/8bitgaming/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/8bitgaming/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/8bitgaming/subscriptions',
#       'organizations_url': 'https://api.github.com/users/8bitgaming/orgs',
#       'repos_url': 'https://api.github.com/users/8bitgaming/repos',
#       'events_url': 'https://api.github.com/users/8bitgaming/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/8bitgaming/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 465940976,
#       'node_id': 'R_kgDOG8Wx8A',
#       'name': 'OgreQuest',
#       'full_name': '8bitgaming/OgreQuest',
#       'private': False,
#       'owner': {'login': '8bitgaming',
#        'id': 79021467,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5MDIxNDY3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/79021467?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/8bitgaming',
#        'html_url': 'https://github.com/8bitgaming',
#        'followers_url': 'https://api.github.com/users/8bitgaming/followers',
#        'following_url': 'https://api.github.com/users/8bitgaming/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/8bitgaming/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/8bitgaming/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/8bitgaming/subscriptions',
#        'organizations_url': 'https://api.github.com/users/8bitgaming/orgs',
#        'repos_url': 'https://api.github.com/users/8bitgaming/repos',
#        'events_url': 'https://api.github.com/users/8bitgaming/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/8bitgaming/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/8bitgaming/OgreQuest',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/8bitgaming/OgreQuest',
#       'forks_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/forks',
#       'keys_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/teams',
#       'hooks_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/hooks',
#       'issue_events_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/events',
#       'assignees_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/tags',
#       'blobs_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/languages',
#       'stargazers_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/stargazers',
#       'contributors_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/contributors',
#       'subscribers_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/subscribers',
#       'subscription_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/subscription',
#       'commits_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/merges',
#       'archive_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/downloads',
#       'issues_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/deployments',
#       'created_at': '2022-03-04T01:26:36Z',
#       'updated_at': '2022-03-05T16:04:32Z',
#       'pushed_at': '2022-03-12T20:45:29Z',
#       'git_url': 'git://github.com/8bitgaming/OgreQuest.git',
#       'ssh_url': 'git@github.com:8bitgaming/OgreQuest.git',
#       'clone_url': 'https://github.com/8bitgaming/OgreQuest.git',
#       'svn_url': 'https://github.com/8bitgaming/OgreQuest',
#       'homepage': None,
#       'size': 9433,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 22,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 22,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': '8bitgaming:main',
#      'ref': 'main',
#      'sha': '920e72b1d0fdbe137c13845f76ccfc256a40182f',
#      'user': {'login': '8bitgaming',
#       'id': 79021467,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5MDIxNDY3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/79021467?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/8bitgaming',
#       'html_url': 'https://github.com/8bitgaming',
#       'followers_url': 'https://api.github.com/users/8bitgaming/followers',
#       'following_url': 'https://api.github.com/users/8bitgaming/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/8bitgaming/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/8bitgaming/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/8bitgaming/subscriptions',
#       'organizations_url': 'https://api.github.com/users/8bitgaming/orgs',
#       'repos_url': 'https://api.github.com/users/8bitgaming/repos',
#       'events_url': 'https://api.github.com/users/8bitgaming/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/8bitgaming/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 465940976,
#       'node_id': 'R_kgDOG8Wx8A',
#       'name': 'OgreQuest',
#       'full_name': '8bitgaming/OgreQuest',
#       'private': False,
#       'owner': {'login': '8bitgaming',
#        'id': 79021467,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5MDIxNDY3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/79021467?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/8bitgaming',
#        'html_url': 'https://github.com/8bitgaming',
#        'followers_url': 'https://api.github.com/users/8bitgaming/followers',
#        'following_url': 'https://api.github.com/users/8bitgaming/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/8bitgaming/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/8bitgaming/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/8bitgaming/subscriptions',
#        'organizations_url': 'https://api.github.com/users/8bitgaming/orgs',
#        'repos_url': 'https://api.github.com/users/8bitgaming/repos',
#        'events_url': 'https://api.github.com/users/8bitgaming/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/8bitgaming/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/8bitgaming/OgreQuest',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/8bitgaming/OgreQuest',
#       'forks_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/forks',
#       'keys_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/teams',
#       'hooks_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/hooks',
#       'issue_events_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/events',
#       'assignees_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/tags',
#       'blobs_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/languages',
#       'stargazers_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/stargazers',
#       'contributors_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/contributors',
#       'subscribers_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/subscribers',
#       'subscription_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/subscription',
#       'commits_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/merges',
#       'archive_url': 'https://api.github.com/repos/8bitgaming/OgreQuest/{archive_format}{/ref}',
# ...
#        'events_url': 'https://api.github.com/users/papitapapita/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/papitapapita/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/papitapapita/POO_project',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/papitapapita/POO_project',
#       'forks_url': 'https://api.github.com/repos/papitapapita/POO_project/forks',
#       'keys_url': 'https://api.github.com/repos/papitapapita/POO_project/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/papitapapita/POO_project/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/papitapapita/POO_project/teams',
#       'hooks_url': 'https://api.github.com/repos/papitapapita/POO_project/hooks',
#       'issue_events_url': 'https://api.github.com/repos/papitapapita/POO_project/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/papitapapita/POO_project/events',
#       'assignees_url': 'https://api.github.com/repos/papitapapita/POO_project/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/papitapapita/POO_project/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/papitapapita/POO_project/tags',
#       'blobs_url': 'https://api.github.com/repos/papitapapita/POO_project/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/papitapapita/POO_project/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/papitapapita/POO_project/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/papitapapita/POO_project/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/papitapapita/POO_project/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/papitapapita/POO_project/languages',
#       'stargazers_url': 'https://api.github.com/repos/papitapapita/POO_project/stargazers',
#       'contributors_url': 'https://api.github.com/repos/papitapapita/POO_project/contributors',
#       'subscribers_url': 'https://api.github.com/repos/papitapapita/POO_project/subscribers',
#       'subscription_url': 'https://api.github.com/repos/papitapapita/POO_project/subscription',
#       'commits_url': 'https://api.github.com/repos/papitapapita/POO_project/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/papitapapita/POO_project/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/papitapapita/POO_project/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/papitapapita/POO_project/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/papitapapita/POO_project/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/papitapapita/POO_project/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/papitapapita/POO_project/merges',
#       'archive_url': 'https://api.github.com/repos/papitapapita/POO_project/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/papitapapita/POO_project/downloads',
#       'issues_url': 'https://api.github.com/repos/papitapapita/POO_project/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/papitapapita/POO_project/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/papitapapita/POO_project/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/papitapapita/POO_project/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/papitapapita/POO_project/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/papitapapita/POO_project/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/papitapapita/POO_project/deployments',
#       'created_at': '2022-03-01T18:29:50Z',
#       'updated_at': '2022-03-09T21:42:30Z',
#       'pushed_at': '2022-03-12T21:24:09Z',
#       'git_url': 'git://github.com/papitapapita/POO_project.git',
#       'ssh_url': 'git@github.com:papitapapita/POO_project.git',
#       'clone_url': 'https://github.com/papitapapita/POO_project.git',
#       'svn_url': 'https://github.com/papitapapita/POO_project',
#       'homepage': None,
#       'size': 142,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'papitapapita:main',
#      'ref': 'main',
#      'sha': '0abb2feb6347ecc33b2c5974cca112aaa59d5a16',
#      'user': {'login': 'papitapapita',
#       'id': 46389562,
#       'node_id': 'MDQ6VXNlcjQ2Mzg5NTYy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/46389562?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/papitapapita',
#       'html_url': 'https://github.com/papitapapita',
#       'followers_url': 'https://api.github.com/users/papitapapita/followers',
#       'following_url': 'https://api.github.com/users/papitapapita/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/papitapapita/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/papitapapita/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/papitapapita/subscriptions',
#       'organizations_url': 'https://api.github.com/users/papitapapita/orgs',
#       'repos_url': 'https://api.github.com/users/papitapapita/repos',
#       'events_url': 'https://api.github.com/users/papitapapita/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/papitapapita/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 465011260,
#       'node_id': 'R_kgDOG7eCPA',
#       'name': 'POO_project',
#       'full_name': 'papitapapita/POO_project',
#       'private': False,
#       'owner': {'login': 'papitapapita',
#        'id': 46389562,
#        'node_id': 'MDQ6VXNlcjQ2Mzg5NTYy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/46389562?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/papitapapita',
#        'html_url': 'https://github.com/papitapapita',
#        'followers_url': 'https://api.github.com/users/papitapapita/followers',
#        'following_url': 'https://api.github.com/users/papitapapita/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/papitapapita/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/papitapapita/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/papitapapita/subscriptions',
#        'organizations_url': 'https://api.github.com/users/papitapapita/orgs',
#        'repos_url': 'https://api.github.com/users/papitapapita/repos',
#        'events_url': 'https://api.github.com/users/papitapapita/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/papitapapita/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/papitapapita/POO_project',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/papitapapita/POO_project',
#       'forks_url': 'https://api.github.com/repos/papitapapita/POO_project/forks',
#       'keys_url': 'https://api.github.com/repos/papitapapita/POO_project/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/papitapapita/POO_project/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/papitapapita/POO_project/teams',
#       'hooks_url': 'https://api.github.com/repos/papitapapita/POO_project/hooks',
#       'issue_events_url': 'https://api.github.com/repos/papitapapita/POO_project/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/papitapapita/POO_project/events',
#       'assignees_url': 'https://api.github.com/repos/papitapapita/POO_project/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/papitapapita/POO_project/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/papitapapita/POO_project/tags',
#       'blobs_url': 'https://api.github.com/repos/papitapapita/POO_project/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/papitapapita/POO_project/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/papitapapita/POO_project/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/papitapapita/POO_project/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/papitapapita/POO_project/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/papitapapita/POO_project/languages',
#       'stargazers_url': 'https://api.github.com/repos/papitapapita/POO_project/stargazers',
#       'contributors_url': 'https://api.github.com/repos/papitapapita/POO_project/contributors',
#       'subscribers_url': 'https://api.github.com/repos/papitapapita/POO_project/subscribers',
#       'subscription_url': 'https://api.github.com/repos/papitapapita/POO_project/subscription',
#       'commits_url': 'https://api.github.com/repos/papitapapita/POO_project/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/papitapapita/POO_project/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/papitapapita/POO_project/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/papitapapita/POO_project/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/papitapapita/POO_project/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/papitapapita/POO_project/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/papitapapita/POO_project/merges',
#       'archive_url': 'https://api.github.com/repos/papitapapita/POO_project/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/papitapapita/POO_project/downloads',
#       'issues_url': 'https://api.github.com/repos/papitapapita/POO_project/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/papitapapita/POO_project/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/papitapapita/POO_project/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/papitapapita/POO_project/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/papitapapita/POO_project/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/papitapapita/POO_project/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/papitapapita/POO_project/deployments',
#       'created_at': '2022-03-01T18:29:50Z',
#       'updated_at': '2022-03-09T21:42:30Z',
#       'pushed_at': '2022-03-12T21:24:09Z',
#       'git_url': 'git://github.com/papitapapita/POO_project.git',
#       'ssh_url': 'git@github.com:papitapapita/POO_project.git',
#       'clone_url': 'https://github.com/papitapapita/POO_project.git',
#       'svn_url': 'https://github.com/papitapapita/POO_project',
#       'homepage': None,
#       'size': 142,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/papitapapita/POO_project/pulls/2'},
#      'html': {'href': 'https://github.com/papitapapita/POO_project/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/papitapapita/POO_project/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/papitapapita/POO_project/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/papitapapita/POO_project/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/papitapapita/POO_project/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/papitapapita/POO_project/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/papitapapita/POO_project/statuses/f1ae6c152ac495f0d8a586e2b2c69bf6e4efad75'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 17,
#     'additions': 3873,
#     'deletions': 44,
#     'changed_files': 46}},
#   'public': True,
#   'created_at': '2022-03-12T21:27:08Z'},
#  {'id': '20717383040',
#   'type': 'PushEvent',
#   'actor': {'id': 6693883,
#    'login': 'AriesLL',
#    'display_login': 'AriesLL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AriesLL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6693883?'},
#   'repo': {'id': 395942364,
#    'name': 'AriesLL/starter-hugo-academic2',
#    'url': 'https://api.github.com/repos/AriesLL/starter-hugo-academic2'},
#   'payload': {'push_id': 9335698205,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '966c3177de5a968ced9aced82a2f3cbc459008d6',
#    'before': '5864cc8bcb929291825cd2c82d14b8a97ef20fa8',
#    'commits': [{'sha': '966c3177de5a968ced9aced82a2f3cbc459008d6',
#      'author': {'email': 'charli@HaotekiMacBook-Air.local',
#       'name': 'Hao Chen'},
#      'message': 'fix link',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AriesLL/starter-hugo-academic2/commits/966c3177de5a968ced9aced82a2f3cbc459008d6'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:08Z'},
#  {'id': '20717383046',
#   'type': 'PushEvent',
#   'actor': {'id': 25337937,
#    'login': 'tangalbert919',
#    'display_login': 'tangalbert919',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tangalbert919',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25337937?'},
#   'repo': {'id': 440925943,
#    'name': 'tangalbert919/android_device_oneplus_sm8350-common',
#    'url': 'https://api.github.com/repos/tangalbert919/android_device_oneplus_sm8350-common'},
#   'payload': {'push_id': 9335698206,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/lineage-19.0',
#    'head': '897a109784133156b348178d7d7ed4fa0d87a86f',
#    'before': '9ed348bd0b3c53de49e910ff9e8eb6cd43f35926',
#    'commits': [{'sha': '87f30bfe9cc8b1d294e5d06e56dcc5a5101f98e2',
#      'author': {'email': 'github@jumoog.io', 'name': 'Kilian von Pflugk'},
#      'message': 'sm8350-common: Remove TARGET_USES_64_BIT_BINDER\n\nThe TARGET_USES_64_BIT_BINDER option is deprecated and can be removed\n\nChange-Id: Ieab43c6baf17eff134a11312d8f8ee7d1b310d55',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tangalbert919/android_device_oneplus_sm8350-common/commits/87f30bfe9cc8b1d294e5d06e56dcc5a5101f98e2'},
#     {'sha': '897a109784133156b348178d7d7ed4fa0d87a86f',
#      'author': {'email': 'georg@vware.at', 'name': 'Georg Veichtlbauer'},
#      'message': 'sm8350-common: Remove CLANG compile flag\n\nDefaults to true now project-wide.\n\nChange-Id: I1e0ff5adadc889d81c90c816457a72d2621e4b5a',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tangalbert919/android_device_oneplus_sm8350-common/commits/897a109784133156b348178d7d7ed4fa0d87a86f'}]},
#   'public': True,
#   'created_at': '2022-03-12T21:27:08Z'}]

# %%
r.json()[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = 'https://pokeapi.co/api/v2/pokemon/'

# %%
# How does that need to adapt for charmander?
charmander_url = base_poke_url + '4/'
charmander_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/4/'

# %%
charmander_url = f' {base_poke_url}4/'
charmander_url
# Out:
# ' https://pokeapi.co/api/v2/pokemon/4/'

# %%
# Check the status code, will this work?
requests.get(charmander_url).status_code
# Out:
# 200

# %%
# Now let's actually get the response (as a json)
char_json = requests.get(charmander_url).json()

# %%
# Let's check out some details about the response
char_json.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
# Check the id
char_json['id']
# Out:
# 4

# %%
# Check the name
char_json['name']
# Out:
# 'charmander'

# %%
# Check the types
char_json['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %% [markdown]
# #### Helper Function!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type _and secondary type_ for that pokemon.
#
# Note that Charmander here just has one type - what would a pokemon with two types look like? Note that Bulbasaur is both grass and poison types.

# %%
char_json
# Out:
# {'abilities': [{'ability': {'name': 'blaze',
#     'url': 'https://pokeapi.co/api/v2/ability/66/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'solar-power',
#     'url': 'https://pokeapi.co/api/v2/ability/94/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 62,
#  'forms': [{'name': 'charmander',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/4/'}],
#  'game_indices': [{'game_index': 176,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 176,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 176,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 4,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 4,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 4,
#    'version': {'name': 'crystal',
#     'url': 'https://pokeapi.co/api/v2/version/6/'}},
#   {'game_index': 4,
#    'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}},
#   {'game_index': 4,
#    'version': {'name': 'sapphire',
#     'url': 'https://pokeapi.co/api/v2/version/8/'}},
#   {'game_index': 4,
#    'version': {'name': 'emerald',
#     'url': 'https://pokeapi.co/api/v2/version/9/'}},
#   {'game_index': 4,
#    'version': {'name': 'firered',
#     'url': 'https://pokeapi.co/api/v2/version/10/'}},
#   {'game_index': 4,
#    'version': {'name': 'leafgreen',
#     'url': 'https://pokeapi.co/api/v2/version/11/'}},
#   {'game_index': 4,
#    'version': {'name': 'diamond',
#     'url': 'https://pokeapi.co/api/v2/version/12/'}},
#   {'game_index': 4,
#    'version': {'name': 'pearl',
#     'url': 'https://pokeapi.co/api/v2/version/13/'}},
#   {'game_index': 4,
#    'version': {'name': 'platinum',
#     'url': 'https://pokeapi.co/api/v2/version/14/'}},
#   {'game_index': 4,
#    'version': {'name': 'heartgold',
#     'url': 'https://pokeapi.co/api/v2/version/15/'}},
#   {'game_index': 4,
#    'version': {'name': 'soulsilver',
#     'url': 'https://pokeapi.co/api/v2/version/16/'}},
#   {'game_index': 4,
#    'version': {'name': 'black',
#     'url': 'https://pokeapi.co/api/v2/version/17/'}},
#   {'game_index': 4,
#    'version': {'name': 'white',
#     'url': 'https://pokeapi.co/api/v2/version/18/'}},
#   {'game_index': 4,
#    'version': {'name': 'black-2',
#     'url': 'https://pokeapi.co/api/v2/version/21/'}},
#   {'game_index': 4,
#    'version': {'name': 'white-2',
#     'url': 'https://pokeapi.co/api/v2/version/22/'}}],
#  'height': 6,
#  'held_items': [],
#  'id': 4,
#  'is_default': True,
#  'location_area_encounters': 'https://pokeapi.co/api/v2/pokemon/4/encounters',
#  'moves': [{'move': {'name': 'mega-punch',
#     'url': 'https://pokeapi.co/api/v2/move/5/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'fire-punch', 'url': 'https://pokeapi.co/api/v2/move/7/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'thunder-punch',
#     'url': 'https://pokeapi.co/api/v2/move/9/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'scratch', 'url': 'https://pokeapi.co/api/v2/move/10/'},
#    'version_group_details': [{'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'swords-dance',
#     'url': 'https://pokeapi.co/api/v2/move/14/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'cut', 'url': 'https://pokeapi.co/api/v2/move/15/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}}]},
#   {'move': {'name': 'wing-attack',
#     'url': 'https://pokeapi.co/api/v2/move/17/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'mega-kick', 'url': 'https://pokeapi.co/api/v2/move/25/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'headbutt', 'url': 'https://pokeapi.co/api/v2/move/29/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}}]},
#   {'move': {'name': 'body-slam', 'url': 'https://pokeapi.co/api/v2/move/34/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'take-down', 'url': 'https://pokeapi.co/api/v2/move/36/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}}]},
#   {'move': {'name': 'double-edge',
#     'url': 'https://pokeapi.co/api/v2/move/38/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}}]},
#   {'move': {'name': 'leer', 'url': 'https://pokeapi.co/api/v2/move/43/'},
#    'version_group_details': [{'level_learned_at': 15,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 15,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}}]},
#   {'move': {'name': 'bite', 'url': 'https://pokeapi.co/api/v2/move/44/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'growl', 'url': 'https://pokeapi.co/api/v2/move/45/'},
#    'version_group_details': [{'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 4,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'ember', 'url': 'https://pokeapi.co/api/v2/move/52/'},
#    'version_group_details': [{'level_learned_at': 9,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 9,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 13,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 4,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'flamethrower',
#     'url': 'https://pokeapi.co/api/v2/move/53/'},
#    'version_group_details': [{'level_learned_at': 38,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 38,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 34,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 34,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 34,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 37,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
# ...
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'work-up', 'url': 'https://pokeapi.co/api/v2/move/526/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'confide', 'url': 'https://pokeapi.co/api/v2/move/590/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}}]},
#   {'move': {'name': 'power-up-punch',
#     'url': 'https://pokeapi.co/api/v2/move/612/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}}]}],
#  'name': 'charmander',
#  'order': 5,
#  'past_types': [],
#  'species': {'name': 'charmander',
#   'url': 'https://pokeapi.co/api/v2/pokemon-species/4/'},
#  'sprites': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/4.png',
#   'back_female': None,
#   'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/shiny/4.png',
#   'back_shiny_female': None,
#   'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/4.png',
#   'front_female': None,
#   'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/4.png',
#   'front_shiny_female': None,
#   'other': {'dream_world': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/dream-world/4.svg',
#     'front_female': None},
#    'home': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/4.png',
#     'front_female': None,
#     'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/4.png',
#     'front_shiny_female': None},
#    'official-artwork': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/4.png'}},
#   'versions': {'generation-i': {'red-blue': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/back/4.png',
#      'back_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/back/gray/4.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/transparent/back/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/4.png',
#      'front_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/gray/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/transparent/4.png'},
#     'yellow': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/back/4.png',
#      'back_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/back/gray/4.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/transparent/back/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/4.png',
#      'front_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/gray/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/transparent/4.png'}},
#    'generation-ii': {'crystal': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/back/shiny/4.png',
#      'back_shiny_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/back/shiny/4.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/back/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/shiny/4.png',
#      'front_shiny_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/shiny/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/4.png'},
#     'gold': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/shiny/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/transparent/4.png'},
#     'silver': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/shiny/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/transparent/4.png'}},
#    'generation-iii': {'emerald': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/emerald/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/emerald/shiny/4.png'},
#     'firered-leafgreen': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/shiny/4.png'},
#     'ruby-sapphire': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/shiny/4.png'}},
#    'generation-iv': {'diamond-pearl': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/shiny/4.png',
#      'front_shiny_female': None},
#     'heartgold-soulsilver': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/shiny/4.png',
#      'front_shiny_female': None},
#     'platinum': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-v': {'black-white': {'animated': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/4.gif',
#       'back_female': None,
#       'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/shiny/4.gif',
#       'back_shiny_female': None,
#       'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/4.gif',
#       'front_female': None,
#       'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/shiny/4.gif',
#       'front_shiny_female': None},
#      'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-vi': {'omegaruby-alphasapphire': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/shiny/4.png',
#      'front_shiny_female': None},
#     'x-y': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-vii': {'icons': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/icons/4.png',
#      'front_female': None},
#     'ultra-sun-ultra-moon': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-viii': {'icons': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-viii/icons/4.png',
#      'front_female': None}}}},
#  'stats': [{'base_stat': 39,
#    'effort': 0,
#    'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}},
#   {'base_stat': 52,
#    'effort': 0,
#    'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}},
#   {'base_stat': 43,
#    'effort': 0,
#    'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}},
#   {'base_stat': 60,
#    'effort': 0,
#    'stat': {'name': 'special-attack',
#     'url': 'https://pokeapi.co/api/v2/stat/4/'}},
#   {'base_stat': 50,
#    'effort': 0,
#    'stat': {'name': 'special-defense',
#     'url': 'https://pokeapi.co/api/v2/stat/5/'}},
#   {'base_stat': 65,
#    'effort': 1,
#    'stat': {'name': 'speed', 'url': 'https://pokeapi.co/api/v2/stat/6/'}}],
#  'types': [{'slot': 1,
#    'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}],
#  'weight': 85}

# %%
# Code here to explore

# %%
# Now - write the function!
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    
    if secondary type is not applicable, secondary type will be 'None'
    '''
    poke_id = poke_resp['id']
    
    poke_name = poke_resp['name']
    
    primary_type = poke_resp['types'][0]['type']['name']
    
    if len(poke_resp['types']) == 1:
        secondary_type = 'None'
    else: 
        secondary_type = poke_resp['types'][1]['type']['name']
        
    poke_details_list = [poke_id, poke_name, primary_type, secondary_type]
        
    return poke_details_list

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
# Run this code to check our work
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'None']
# [7, 'squirtle', 'water', 'None']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import panda
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the `time` library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
# Let's write this together!
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(.5)
# Then, concat everything into one df
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df.tail()
# Out:
#       id       name primary_type secondary_type
# 146  147    dratini       dragon           None
# 147  148  dragonair       dragon           None
# 148  149  dragonite       dragon         flying
# 149  150     mewtwo      psychic           None
# 150  151        mew      psychic           None

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)


# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/zachrauch/.secret/Keys.json")

# Setting the first (and only) value as a variable
api_keys['tmdb_key'][0]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-37-816638e0b906> in <module>
#      12
#      13 # Using the function to open and load all keys in that file
# ---> 14 api_keys = get_keys("/Users/zachrauch/.secret/Keys.json")
#      15
#      16 # Setting the first (and only) value as a variable
#
# <ipython-input-37-816638e0b906> in get_keys(path)
#       8 def get_keys(path):
#       9     with open(path) as f:
# ---> 10         return json.load(f)
#      11
#      12
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_api_key

tmdb_2 = tmdb_api_key



# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!

example_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_2}"

# %%
# Get the response

r = requests.get(example_url).json()

# %%
# Check the keys

r
# Out:
# {'adult': False,
#  'backdrop_path': '/rr7E0NoGKxvbkb89eR1GwfoYjpA.jpg',
#  'belongs_to_collection': None,
#  'budget': 63000000,
#  'genres': [{'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.foxmovies.com/movies/fight-club',
#  'id': 550,
#  'imdb_id': 'tt0137523',
#  'original_language': 'en',
#  'original_title': 'Fight Club',
#  'overview': 'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.',
#  'popularity': 88.993,
#  'poster_path': '/pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg',
#  'production_companies': [{'id': 508,
#    'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png',
#    'name': 'Regency Enterprises',
#    'origin_country': 'US'},
#   {'id': 711,
#    'logo_path': '/tEiIH5QesdheJmDAqQwvtN60727.png',
#    'name': 'Fox 2000 Pictures',
#    'origin_country': 'US'},
#   {'id': 20555,
#    'logo_path': '/hD8yEGUBlHOcfHYbujp71vD8gZp.png',
#    'name': 'Taurus Film',
#    'origin_country': 'DE'},
#   {'id': 54051,
#    'logo_path': None,
#    'name': 'Atman Entertainment',
#    'origin_country': ''},
#   {'id': 54052,
#    'logo_path': None,
#    'name': 'Knickerbocker Films',
#    'origin_country': 'US'},
#   {'id': 4700,
#    'logo_path': '/A32wmjrs9Psf4zw0uaixF0GXfxq.png',
#    'name': 'The Linson Company',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '1999-10-15',
#  'revenue': 100853753,
#  'runtime': 139,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Mischief. Mayhem. Soap.',
#  'title': 'Fight Club',
#  'video': False,
#  'vote_average': 8.4,
#  'vote_count': 23643}

# %%
#Check the keys
r.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
example_id = r['id']
example_id
# Out:
# 550

# %%
# Find similar movies to the previous id
base_url = 'https://api.themoviedb.org/3/'

similar_movie_url = f"{base_url}/movie/{example_id}/similar?api_key={tmdb_2}"

# %%
# Check out that response

r = requests.get(similar_movie_url).json()

# %%
r.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
# How many similar movies did it find?

r['total_results']
# Out:
# 10000

# %%
# but is that the length of these results?

len(r['results'])
# Out:
# 20

# %%
# what's in here?

r['results'][0]
# Out:
# {'adult': False,
#  'backdrop_path': '/pV3851nZ1OZ18j2BWDJSQ4de0Dn.jpg',
#  'genre_ids': [28, 18, 9648, 53, 80],
#  'id': 9415,
#  'title': 'Murder at 1600',
#  'original_language': 'en',
#  'original_title': 'Murder at 1600',
#  'overview': "A secretary is found dead in a White House bathroom during an international crisis, and Detective Harlan Regis is in charge of the investigation. Despite resistance from the Secret Service, Regis partners with agent Nina Chance. As political tensions rise, they learn that the crime could be part of an elaborate cover-up. Framed as traitors, the pair, plus Regis' partner, break into the White House in order to expose the true culprit.",
#  'popularity': 20.396,
#  'poster_path': '/5S469MSJIzb6J0PIsghUn52uzfP.jpg',
#  'release_date': '1997-04-18',
#  'video': False,
#  'vote_average': 6.0,
#  'vote_count': 399}

# %% [markdown]
# ## Level Up - Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit - Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
